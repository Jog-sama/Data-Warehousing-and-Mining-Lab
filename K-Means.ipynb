# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import numpy as np

frame1 = pd.read_csv('CollegeLake_Exam_scores.csv')


X = frame1["cgpa"]
y = frame1["gre_score"]

# %%
dataset = frame1[["cgpa", "gre_score"]].to_numpy()

# %%
dataset.shape
# Out:
# (100, 2)

# %%
plt.rcParams['figure.figsize'] = (30, 10)
plt.scatter(X, y, alpha=0.3)
plt.xlim(3, 4)
plt.ylim(260, 340)
plt.title('CGPA vs GRE score')
plt.xlabel('CGPA')
plt.ylabel('GRE_Scores')
# Out:
# Text(0, 0.5, 'GRE_Scores')

# %%
X.shape
# Out:
# (100,)

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(dataset)
y_kmeans = kmeans.predict(dataset)

# %%
y_kmeans
# Out:
# array([1, 1, 2, 1, 2, 2, 1, 1, 1, 2, 1, 2, 2, 0, 1, 0, 2, 0, 2, 2, 1, 0,
#        1, 0, 0, 1, 2, 1, 1, 1, 1, 0, 0, 2, 0, 2, 0, 0, 1, 2, 0, 1, 0, 2,
#        0, 2, 1, 1, 1, 1, 1, 1, 1, 2, 2, 0, 2, 2, 1, 0, 1, 1, 2, 2, 1, 2,
#        2, 1, 1, 2, 2, 2, 0, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 0, 0, 2, 0, 2,
#        2, 2, 2, 1, 1, 0, 1, 0, 0, 0, 0, 0])

# %%
centers = kmeans.cluster_centers_
plt.scatter(dataset[:, 0], dataset[:, 1], c=y_kmeans, s=50, cmap="viridis")
plt.scatter(centers[:, 0], centers[:, 1], c="black", s=200, alpha=0.5)
plt.show()
